# %% [markdown]
# # Các thư viện, chưa biết có cần thiết hay không
# Libraries, not sure all of them are necessary

# %%
import os
import random

import undetected_chromedriver as uc
import time 
from selenium.webdriver.common.by import By

import json
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

from datetime import datetime
from datetime import timedelta

from bs4 import BeautifulSoup

import subprocess


from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi 

import pandas as pd

# %% [markdown]
# # Mongodb

# %%
# Đây là liên kết tới database của tôi
# Uri connects to my database (Atlas for sure)
MONGODB_URI = "mongodb+srv://MasterMind:MasterMind@productpage.nj9srv4.mongodb.net/"

# %%
# Hàm gọi kết nối tới mongodb
# Funtion that makes a connection to my database
def CONNECT_MONGODB(uri = MONGODB_URI) : 
    client = MongoClient(uri, server_api=ServerApi('1'))

    # ping để kiểm tra xem có kết nối thành công hay không
    # ping to check if it was successful
    try:
        client.admin.command('ping')
        print("Pinged your deployment. You successfully connected to MongoDB!")
        return client,True
    except Exception as e:
        print(e)
        return client,False

# %% [markdown]
# # VPN

# %%
# Nơi chứa các file Ipvanish .ovpn
# Location of .ovpn file 
OVPNS_LOCATION = 'C:\Program Files\OpenVPN\config' 
# Nơi thực thi openvpn-gui
# Location of openvpn-gui 
OPENVPN_GUI = '\"C:\\Program Files\\OpenVPN\\bin\\openvpn-gui.exe\"'

# %%
# Hàm kết nối đến VPN 
# Funtion that establishs a connection to VPN 
def CONNECT_VPN(ovpn) : 
    # kiểm tra ip lúc đầu
    print("connecting to ",ovpn)
    result = subprocess.check_output(["curl", "ifconfig.co"])
    ip_address_current = result.decode('utf-8').strip()

    ip_changed = False
    # !{OPENVPN_GUI} --command connect {ovpn}
    timeout = 20
    # Đợi cho đến khi VPN đã được kết nối và làm thay đổi ip 
    # Wait until VPN changed my ip
    while not ip_changed and timeout > 0: 
        result = subprocess.check_output(["curl", "ifconfig.co"])
        ip_address_after = result.decode('utf-8').strip()
        if ip_address_after!= ip_address_current : 
            ip_changed = True
        else : 
            # Nếu đợi quá lâu, nên dừng lại 
            # Stop if had waited for a long time
            time.sleep(2)
            timeout -=2
            if timeout<=0 : break



# Hàm ngắt kết nối đến VPN 
# Diconnection to VPN function
def DISCONNECT_VPN(ovpn) :
    print("disconnecting to ",ovpn)
    result = subprocess.check_output(["curl", "ifconfig.co"])
    ip_address_current = result.decode('utf-8').strip()

    ip_changed = False
    # !{OPENVPN_GUI} --command disconnect {ovpn}
    timeout = 20
    while not ip_changed and timeout > 0: 
        result = subprocess.check_output(["curl", "ifconfig.co"])
        ip_address_after = result.decode('utf-8').strip()
        if ip_address_after!= ip_address_current : 
            ip_changed = True
        else : 
            time.sleep(2)
            timeout -=2
            if timeout <= 0 : break

#Load
OVPNS = [i for i in os.listdir(OVPNS_LOCATION) if i.endswith('.ovpn')]

# %% [markdown]
# # Tài khoản Shopee
# Shopee account

# %%
# Tất cả các account hiện có của tôi. Cấu trúc của chúng như phần ghi chú, giải thích sẽ ở phần # Shopee_Selenium 
# My own shopee accounts, structure likes below, explain in # Shopee_Selenium 
SHOPEE_ACCOUNTS = pd.read_csv('SHOPEE_ACCOUNTS.csv')
SHOPEE_ACCOUNTS = SHOPEE_ACCOUNTS.to_dict('records')
# SHOPEE_ACCOUNTS  = [{'username' : '', 'password' : '','email_user' : '','email_domain' : 'https://mailnesia.com/mailbox/','current_ovpn' :'', 'end_ovpn' : 0},
#                    {'username' : '', 'password' : '','email_user' : '','email_domain' : 'https://mailnesia.com/mailbox/','current_ovpn' :'', 'end_ovpn' : 0},
#                    {'username' : '', 'password' : '','email_user' : '','email_domain' : 'https://mailnesia.com/mailbox/','current_ovpn' :'', 'end_ovpn' : 0},
#                    {'username' : '', 'password' : '','email_user' : '','email_domain' : 'https://mailnesia.com/mailbox/','current_ovpn' :'', 'end_ovpn' : 0},
#                    {'username' : '', 'password' : '','email_user' : '','email_domain' : 'https://mailnesia.com/mailbox/','current_ovpn' :'', 'end_ovpn' : 0}]

# %%
# Hàm lấy ra ngẫu nhiên account 
# Make a sample
def SWITCH_ACCOUNT(shopee_account,shopee_accounts) : 
    shopee_account_current = shopee_account
    while shopee_account == shopee_account_current : 
        shopee_account = random.choice(shopee_accounts)
    return shopee_account

# %% [markdown]
# # Chromnium

# %%
# Cài đặt cần thiết cho việc bắt các gói phản hồi
# Requre for capture Network
CAPS = DesiredCapabilities.CHROME

CAPS['goog:loggingPrefs'] = {'performance': 'ALL'}

# %% [markdown]
# # Trang đăng nhập
# Login page

# %%
# javascript dùng để giả lập một cú click chuột vào ô tên đăng nhập, mật khẩu
# javascript code simulating a focus event (username and password input)
JC_USERNAME_FOCUS = 'document.querySelector(\'[name="loginKey"]\').focus();'
JC_PASSWORD_FOCUS = 'document.querySelector(\'[name="password"]\').focus();'

# javascript dùng để đăng nhập
# javascript code simulating submit login form
JC_LOGIN_CLICK = 'document.querySelector(\'* > button:not(:has(*))\').click()'

# javascript dùng để thực hiện giả lập nhập từ bàn phím
# javascript code simulating input from keyboard (need to be formated)
JC_SIM_INPUT= "document.execCommand(\'insertText\', false, \'{}\');"

# %%
# Hàm bắt chromedriver thực hiện đăng nhập vào shopee khi đang ở trang đăng nhập 
# Force chromdriver login to shopee when already on login page
def SHOPEE_LOGIN(driver,username,password) : 
    
    print("Login as :",username,password)

    driver.execute_script(JC_USERNAME_FOCUS)
    driver.execute_script(JC_SIM_INPUT.format(username))
    
    driver.execute_script(JC_PASSWORD_FOCUS)
    driver.execute_script(JC_SIM_INPUT.format(password))

    driver.execute_script(JC_LOGIN_CLICK)

# %% [markdown]
# # Trang xác nhận thiết bị
# Verify device page

# %%
# javascript dùng để bấm vào nút nhận email
# javascript use to click send email button 
JC_VERIFY_BUTTON_CLICK = 'document.querySelector("button:has(svg)").click()'

# javascript dùng để tìm email shopee gửi tới
# javascript use to find email that shopee just send
JC_VERIFY_EMAIL_SELECT = 'document.querySelectorAll("tr")[1].click()'

# javascript dùng để bấm vào nút gửi lại email 
# javascript use to click resend email button 
JC_RESEND_VERIFY_EMAIL = 'document.querySelector(\'button[aria-label="Click the button to resend the authentication link"]\').click()'

# CSS Selector dùng để tìm liên kết xác nhận 
# CSS Selector find verify link
CS_VERIFY_LINK = "tr > * > div > b >a"

# %%
# Hàm dùng để tự động xác nhận thiết bị  
# like its name
def AUTO_VERIFY_DEVICE(driver,email_domain,email_user) : 
    if 'verify' in  driver.current_url : 

        # Bấm gửi/Click send
        driver.execute_script(JC_VERIFY_BUTTON_CLICK)
        
        # 1 Chromedriver mới để nhận liên kết xác nhận 
        # 1 new Chromedriver to get verify link
        driver_temp = uc.Chrome(headless=False,use_subprocess=False,desired_capabilities=CAPS)
        time.sleep(15)
        # Số lần kiểm tra email tối đa là 3/ max is 3 times check mail 
        loop =3 
        def check_mail(loop) : 
            # Điều kiện là 'login=true'/ success state is 'login=true'
            while 'login=true' not in driver.current_url and loop > 0: 
                print('Start GET')
                driver_temp.get( email_domain+email_user)
                
                time.sleep(10)
                if 'login=true' in driver.current_url : 
                    break
                driver_temp.execute_script(JC_VERIFY_EMAIL_SELECT)
                time.sleep(5)

                next_url = driver_temp.find_element(By.CSS_SELECTOR,CS_VERIFY_LINK).get_attribute('href')
                driver_temp.get(next_url)
                loop -=1
                time.sleep(2)
            return loop
        
        loop = check_mail(loop)
        # Đôi khi email không được gửi đi, bấm gửi lại và check mail thêm 2 lần nữa 
        # Sometime email is not send, hit resend and try 2 more times 
        if 'login=true' not in driver.current_url and loop <= 0 : 
            time.sleep(30)
            if 'login=true' not in driver.current_url : 
                print('click resend')
                driver.execute_script(JC_RESEND_VERIFY_EMAIL)
                time.sleep(15)
                check_mail(2)

        time.sleep(1)
        driver_temp.close()
        driver_temp.quit()
        # Tạo lỗi nếu không thành công/ cause an exception if not success
        assert 'login=true' in driver.current_url

# %% [markdown]
# # Trang chủ
# Home page

# %%
# javascript dùng để bấm vào nút tắt popup 
# javascript use to click close popup 
JS_CLOSE_POPUP = 'document.getElementsByTagName("shopee-banner-popup-stateful")[0].shadowRoot.querySelector(".shopee-popup__close-btn").click()'

# %% [markdown]
# # Trang tìm kiếm
# searching page

# %%
JC_SEARCH_FOCUS =  "document.querySelector('.shopee-searchbar-input > input').focus()"
JC_SEARCH_CLICK = "document.querySelector('button.shopee-searchbar__search-button').click()"
JS_QUERY_ITEMS_TAG ='document.querySelector(\'div.shopee-search-item-result__items > * >a[href*="{}"]\')'
JS_SIM_DELETE = 'document.execCommand("delete")'

# %%
def SEARCH_ITEM(driver,item_name) : 
    print("Seaching ",item_name) 

    driver.execute_script(JC_SEARCH_FOCUS)
    driver.execute_script(JC_SIM_INPUT.format(item_name))
    driver.execute_script(JC_SEARCH_CLICK)

def GO_TO_ITEM(driver,item_link) :
    driver.execute_script(JS_QUERY_ITEMS_TAG.format(item_link) + '.scrollIntoView({ behavior : "smooth", })')
    time.sleep(random.uniform(1.5,2.5))
    driver.execute_script(JS_QUERY_ITEMS_TAG.format(item_link) + '.click()')

def DELETE_SEARCH_BAR(driver,item_name) :
    driver.execute_script(JC_SEARCH_FOCUS)
    for i in range(len(item_name)+1) : 
        driver.execute_script(JS_SIM_DELETE)

# %% [markdown]
# # Shopee_Selenium

# %%
#Shopee 
SHOPEE_LOGIN_URL = 'https://shopee.vn/buyer/login'
CAMPAIN_URL = "https:/shopee.vn/Thời-Trang-Nam-cat.11035567"
CATEGORY_URL = "https://shopee.vn/mall/brands/11035567"

# %%
#DELAY
def DELAY(secs): 
    delay = random.uniform(max(0,secs-0.5), secs+1.5)
    time.sleep(delay)

# %%
# 1 Class để thực thi công việc tuần tự. Bởi vì để đảm bảo ngưỡng số lượng truy vấn an toàn thì việc lập trình đa luồng là không cần thiết nữa 
# A Class to manual process our work sequentially. Since we need to keep a threshold of number requests, threading is no longer necessary.
class ShopeeProductCore : 
    def __init__(self) -> None:
        # Đầu tiên là tạo một chromedriver với cài đặt bổ sung, thư viện sử dụng là undetected_chromedriver 
        # First of all, we create a chromedriver, using undetected_chromedriver library
        self.caps = CAPS
        self.driver = uc.Chrome(headless=False,use_subprocess=False,desired_capabilities=self.caps)

        # Giờ chỉ cần trỏ các hàm bên trong tới các hàm đã làm sẵn ở bên ngoài
        # Just point to funtions we created 
        self.shopee_accounts = SHOPEE_ACCOUNTS

        self.connect_mongodb = CONNECT_MONGODB

        self.connect_vpn = CONNECT_VPN
        self.disconnect_vpn = DISCONNECT_VPN
        self.ovpns = OVPNS
        self.ovpn = ''

        self.switch_account = SWITCH_ACCOUNT
        
        self.delay = DELAY

        self.login = SHOPEE_LOGIN
        self.auto_verify_device = AUTO_VERIFY_DEVICE

        self.search_item = SEARCH_ITEM
        self.go_to_item = GO_TO_ITEM
        self.delete_search_bar = DELETE_SEARCH_BAR

    def get_driver(self): 
        return self.driver
    
    # Đôi khi, shopee sẽ tự động chuyển hướng chúng ta tới 1 trang khác, 
    # hàm này giúp giữ nguyên trạng thái chromedriver cho đến khi có người xử lí trực tiếp trên trình duyệt 
    # Sometime, shopee would redirect us, this function appears to handle that (btw, I had never get that situation)
    def __check_fail_get(self):
        while not self.driver.current_url.startswith("https://shopee.vn/") : 
            time.sleep(10)
    
    # Bắt đầu tạo các hàm riêng của ShopeeCore. 
    # Vì sao các hàm này không được trình bày ở bên ngoài sau đó chỉ cần tạo các biến self trỏ đến? 
    # Đơn giản thì đây là các hàm thực thi pipeline chính, các hàm được tạo bên ngoài là phụ gia để pipeline ổn định
    # Functions belong to ShopeeCore, on its own
    # Why these are not pointed like other? Simply, These are required for the main pipeline, those other are additives

    # Tôi sẽ thêm #### vào những nơi thuộc về cá nhân hóa của tôi
    # Ngoài ra còn có các đặc trưng (gói tin, liên kết,... ) nó sẽ là cố định đối với ShopeeCore
    # I will add #### to mark where is my custom 
    # Its characteristics (respone, link,... ) are embedded to this code, so I won't mark them. 
    # It works fine this time, but I believe that if shopee updates, shopeeCore won't reusable

    # Hàm này bắt tất cả gói tin đã yêu cầu trong 1 phiên duyệt. 
    # This function capture all respones of one seasion
    def __capture_event(self): 
        
        # get_log('performance') sẽ trả về rỗng sau khi thực hiện 1 lần
        # get_log('performance') would be empty if this called one time
        browser_log = self.driver.get_log('performance') 
        events = [json.loads(entry['message'])['message'] for entry in browser_log]
        events = [event for event in events if 'Network.response' in event['method']]
        return events
    
    # Hàm này dùng để lấy `requestId của phản hồi có `url chứa  `key
    # This function fetch `requestId whose `url has substring `key 
    def __fetch_first_match_event(self,events,key) : 
        requestId = None
        for i in events : 
            try : 
                if key in i["params"]["response"]["url"] : 
                    requestId = i["params"]["requestId"]
                    break
            except : 
                pass
        return requestId

    # Bắt phản hồi chứa thông tin sản phẩm, sau đó đẩy lên đám mây 
    # Capture respone that has item's infor, then push them to clouds
    def __fetch_push_items(self,client,requestId,shopid):
        time_now = int(datetime.now().strftime("%Y%m%d%H%M%S"))
        itemInfo = self.driver.execute_cdp_cmd('Network.getResponseBody', {'requestId': requestId})
        itemInfo = json.loads(itemInfo['body'])['data']
####
        items = {
            'shopid' : shopid,
            'items' : itemInfo,
            'version' : 1,
            'updated_time' : time_now,
        }
####    
        # `database = 'product_pages', `collection = 'items'
        db_landing_page = client.get_database('product_pages')
        records = db_landing_page.items

        records.insert_one(items)
    

    def __make_new_driver(self) : 
        self.driver = uc.Chrome(headless=False,use_subprocess=False,desired_capabilities=self.caps)

    def quit_driver(self):
        self.driver.close()
        self.driver.quit()
        self.driver = None; 


    # Pipeline 

    # đăng nhập/login  -> xác nhận thiết bị/verify device -> tắt popup (nếu có)/close popup (if exsist)
    # -> chuyển tiếp như con người/redirect like human -> (loop) 
    # (loop)
    # trang danh mục/category page -> tìm thẻ shop/looking for shop -> lướt qua tất cả các trang/checkout all shop's pages 
    # -> trở về trang trước dó/backward
    def pipeline(self) : 
        
        # Kết nối tới Atlas 
        # connect to mongodb
        shopee_account = ''
        client,status = self.connect_mongodb(MONGODB_URI)
        print("Client status :",status)

        # Làm vô tận cho đến khi nào lỗi hoặc đã thăm tất cả shop.
        # infinity loop till cause an exception or done
        # Easy to debug
        while True : 

            # Lấy ra ngẫu nhiên một tài khoản
            # Pick a random account 
            shopee_account = self.switch_account(shopee_account,self.shopee_accounts)
####
            # Số lượng shop tối đa một phiên truy vấn 
            items_max = 30

            # ovpn sẽ được chọn ngẫu nhiên, tuy nhiên nếu tài khoản vẫn còn đang trong thời gian sử dụng ovpn thì sẽ lại sử dụng opvn đó
            # Thuộc tính `current_ovpn, `end_ovpn kiểm soát điều này
            # randomchoise ovpn, but account `current_ovpn exsist and its `end_ovpn show that still in time, use `current_ovpn instead
            ovpn = random.choice(self.ovpns)
            if not shopee_account['current_ovpn'] : 

                if shopee_account['end_ovpn'] < int(datetime.now().strftime("%Y%m%d%H%M%S")): 
                    shopee_account['current_ovpn'] = ovpn

                    # Nếu thời gian sử dụng ovpn đã kết thúc, nên cho nó 1 vpn ngẫu nhiên khác, điều này tránh việc tài khoản dùng quá nhiều ip 
                    # Overtime? Set a new ovpn, this will avoid an account uses too much ip 
                    shopee_account['end_ovpn'] = int((datetime.now() + timedelta(hours=2)).strftime("%Y%m%d%H%M%S"))
                    self.shopee_accounts = [i for i in self.shopee_accounts if i['username'] != shopee_account['username']]
                    self.shopee_accounts.append(shopee_account)
                    print("new vpn assigned")
                else : 
                    ovpn = self.shopee_account['current_ovpn']

            # kết nối vpn/ connect vpn
            self.connect_vpn(ovpn)
            self.ovpn = ovpn

####        
            # Lưu lại thông tin các account cho lần chạy tiếp theo (thường là lỗi do debug)
            # Save accounts'info for next time (rerun after fix debug)
            pd.DataFrame.from_dict(self.shopee_accounts).to_csv('SHOPEE_ACCOUNTS.csv',index=False)

            # login
            self.driver.get(SHOPEE_LOGIN_URL)
            print("start get SHOPEE_LOGIN_URL")
            self.delay(10)

            # username password
            print("start input username password")
            self.login(self.driver,shopee_account['username'],shopee_account['password'])
            self.delay(10)
            self.auto_verify_device(self.driver,shopee_account['email_domain'],shopee_account['email_user'])
            self.delay(15)

            # Tắt popup (nếu có)/ close popup (if exsist)
            try : 
                self.driver.execute_script(JS_CLOSE_POPUP)
    
                print("pass JS_CLOSE_POPUP")
                self.delay(1.5)
            except : 
                pass 
            
            item_taget = None
            while items_max : 
                
####    
                # `database = 'products', `collection = 'products'
                db_products = client.get_database('products')
                records = db_products.products

                
                time_now = int(datetime.now().strftime("%Y%m%d%H%M%S"))
####                

                item_taget =  records.find_one({'visited' : False,'onFetching_timeout' : {"$lt" : time_now}})

                time_then = int((datetime.now() + timedelta(hours=5)).strftime("%Y%m%d%H%M%S"))
                records.update_one({'link' : item_taget['link']},[{ '$set':  {'onFetching_timeout' : time_then} }])

                print("item taget : ",item_taget)

                self.search_item(self.driver,item_taget['name'])
                self.delay(8)
                try : 
                    self.go_to_item(self.driver,item_taget['link'])
                    self.delay(10)
                except : 
                    records.update_one({'link' : item_taget['link']},[{ '$set': { "visited":True} }])
                    self.delete_search_bar(self.driver,item_taget['name'])
                    continue
                
                # events 'get_shop_base' , 'rcmd_items'
                events = self.__capture_event()
                
                #__fetch_push_shop_base
                print("get_pc")
                requestId =  self.__fetch_first_match_event(events,'get_pc')
                self.__fetch_push_items(client,requestId,item_taget['shopid'])

                self.driver.back()
                self.delete_search_bar(self.driver,item_taget['name'])
                self.delay(1)
                
                #"done one items"
                print("done one shop")
                records = db_products.products
                records.update_one({'link' : item_taget['link']},[{ '$set': { "visited":True} }])
                items_max-=1
            

            self.quit_driver()
            self.__make_new_driver()
            self.disconnect_vpn(ovpn)
            if not item_taget : 
                    break

# %%
#Open app openvpn first 
    
#Delete C:\Users\<user>\AppData\Local\Temp frequently
#Close VSCode, restart python, close browser frequently

# %%
Shopee =  ShopeeProductCore()
try : 
    print('start subprocess')
    Shopee.pipeline()
except Exception as e:
    print(e) 
    Shopee.quit_driver()
    DISCONNECT_VPN(Shopee.ovpn)
# Out:
# start subprocess
# Pinged your deployment. You successfully connected to MongoDB!
# Client status : True
# connecting to  ipvanish-US-Dallas-dal-a53.ovpn
# start get SHOPEE_LOGIN_URL
# start input username password
# Login as : vuongnghiaunepa Redbrhihpgl
# Start GET
# Start GET
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d7c'), 'shopid': 257412160, 'name': 'Áo polo nam cổ trụ tay ngắn AREMI thiết kế đơn giản hình thêu chắc chắn phong cách trẻ trung thanh lịch APL0030', 'link': '/Áo-polo-nam-cổ-trụ-tay-ngắn-AREMI-thiết-kế-đơn-giản-hình-thêu-chắc-chắn-phong-cách-trẻ-trung-thanh-lịch-APL0030-i.257412160.24600479760', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo nam cổ trụ tay ngắn AREMI thiết kế đơn giản hình thêu chắc chắn phong cách trẻ trung thanh lịch APL0030
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d7d'), 'shopid': 257412160, 'name': 'Quần lót nam, BOXER dáng sịp đùi AREMI, vải cotton co giãn 4 chiều, thiết kế thoải mái', 'link': '/Quần-lót-nam-BOXER-dáng-sịp-đùi-AREMI-vải-cotton-co-giãn-4-chiều-thiết-kế-thoải-mái-i.257412160.4347208664', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Quần lót nam, BOXER dáng sịp đùi AREMI, vải cotton co giãn 4 chiều, thiết kế thoải mái
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d7e'), 'shopid': 257412160, 'name': 'Áo thun nam cổ tròn, T-shirt nam đen in AREMI, chất liệu cotton cao cấp, thiết kế sang trọng ATS0010', 'link': '/Áo-thun-nam-cổ-tròn-T-shirt-nam-đen-in-AREMI-chất-liệu-cotton-cao-cấp-thiết-kế-sang-trọng-ATS0010-i.257412160.10307538128', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo thun nam cổ tròn, T-shirt nam đen in AREMI, chất liệu cotton cao cấp, thiết kế sang trọng ATS0010
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d7f'), 'shopid': 257412160, 'name': 'Áo polo nam tay ngắn thun nam có cổ AREMI chất liệu cá sấu cotton co giản 4 chiều thiết kế đơn giản sang trọng APL0033', 'link': '/Áo-polo-nam-tay-ngắn-thun-nam-có-cổ-AREMI-chất-liệu-cá-sấu-cotton-co-giản-4-chiều-thiết-kế-đơn-giản-sang-trọng-APL0033-i.257412160.18885999625', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo nam tay ngắn thun nam có cổ AREMI chất liệu cá sấu cotton co giản 4 chiều thiết kế đơn giản sang trọng APL0033
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d80'), 'shopid': 257412160, 'name': 'Quần short nam form dáng trẻ trung AREMI chất liệu kaki dày dặn thiết kế phong cách thoải mái sang trọng', 'link': '/Quần-short-nam-form-dáng-trẻ-trung-AREMI-chất-liệu-kaki-dày-dặn-thiết-kế-phong-cách-thoải-mái-sang-trọng-i.257412160.23182927071', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Quần short nam form dáng trẻ trung AREMI chất liệu kaki dày dặn thiết kế phong cách thoải mái sang trọng
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d81'), 'shopid': 257412160, 'name': 'Áo thun nam cổ tròn, T-SHIRT trơn màu đen AREMI, vải Cotton co giãn 4 chiều ATS0003', 'link': '/Áo-thun-nam-cổ-tròn-T-SHIRT-trơn-màu-đen-AREMI-vải-Cotton-co-giãn-4-chiều-ATS0003-i.257412160.3564427851', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo thun nam cổ tròn, T-SHIRT trơn màu đen AREMI, vải Cotton co giãn 4 chiều ATS0003
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d82'), 'shopid': 257412160, 'name': 'Áo thun nam cổ tròn tay ngắn AREMI chất liệu cotton co giản 4 chiều thiết kế form dáng trẻ trung thanh lịch ATS0008', 'link': '/Áo-thun-nam-cổ-tròn-tay-ngắn-AREMI-chất-liệu-cotton-co-giản-4-chiều-thiết-kế-form-dáng-trẻ-trung-thanh-lịch-ATS0008-i.257412160.22486138651', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo thun nam cổ tròn tay ngắn AREMI chất liệu cotton co giản 4 chiều thiết kế form dáng trẻ trung thanh lịch ATS0008
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d83'), 'shopid': 257412160, 'name': 'Áo Polo nam cổ trụ tay ngắn AREMI, màu đen in thiết kế độc đáo phong cách sang trọng APL0074', 'link': '/Áo-Polo-nam-cổ-trụ-tay-ngắn-AREMI-màu-đen-in-thiết-kế-độc-đáo-phong-cách-sang-trọng-APL0074-i.257412160.21523531997', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo Polo nam cổ trụ tay ngắn AREMI, màu đen in thiết kế độc đáo phong cách sang trọng APL0074
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d84'), 'shopid': 257412160, 'name': 'Áo thun nam tay ngắn cổ tròn AREMI chất liệu cotton dày dặn thiết kế phong cách sang trọng ATS0007', 'link': '/Áo-thun-nam-tay-ngắn-cổ-tròn-AREMI-chất-liệu-cotton-dày-dặn-thiết-kế-phong-cách-sang-trọng-ATS0007-i.257412160.23485613118', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo thun nam tay ngắn cổ tròn AREMI chất liệu cotton dày dặn thiết kế phong cách sang trọng ATS0007
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d85'), 'shopid': 257412160, 'name': 'Áo polo đen nam tay ngắn cổ trụ phối độc lạ chính hãng AREMI vải co giãn 4 chiều cao cấp thiết kế thanh lịch APL0038', 'link': '/Áo-polo-đen-nam-tay-ngắn-cổ-trụ-phối-độc-lạ-chính-hãng-AREMI-vải-co-giãn-4-chiều-cao-cấp-thiết-kế-thanh-lịch-APL0038-i.257412160.23637254107', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo đen nam tay ngắn cổ trụ phối độc lạ chính hãng AREMI vải co giãn 4 chiều cao cấp thiết kế thanh lịch APL0038
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d86'), 'shopid': 257412160, 'name': 'Áo thun nam tay raglan AREMI t-shirt trơn cổ tròn chất liệu cotton dày dặn thấm hút tốt phong cách sang trọng', 'link': '/Áo-thun-nam-tay-raglan-AREMI-t-shirt-trơn-cổ-tròn-chất-liệu-cotton-dày-dặn-thấm-hút-tốt-phong-cách-sang-trọng-i.257412160.25200820330', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo thun nam tay raglan AREMI t-shirt trơn cổ tròn chất liệu cotton dày dặn thấm hút tốt phong cách sang trọng
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d87'), 'shopid': 257412160, 'name': 'Áo thun nam T-shirt trơn AREMI màu trắng, chất Liệu cotton 4 chiều form chuẩn phong cách đơn giản ATS0002', 'link': '/Áo-thun-nam-T-shirt-trơn-AREMI-màu-trắng-chất-Liệu-cotton-4-chiều-form-chuẩn-phong-cách-đơn-giản-ATS0002-i.257412160.6953891578', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo thun nam T-shirt trơn AREMI màu trắng, chất Liệu cotton 4 chiều form chuẩn phong cách đơn giản ATS0002
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d88'), 'shopid': 257412160, 'name': 'Áo thun polo nam tay ngắn cổ trụ AREMI chất liệu CVC mới thiết kế sang trọng thanh lịch phong cách lịch lãm APL0016', 'link': '/Áo-thun-polo-nam-tay-ngắn-cổ-trụ-AREMI-chất-liệu-CVC-mới-thiết-kế-sang-trọng-thanh-lịch-phong-cách-lịch-lãm-APL0016-i.257412160.18584419685', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo thun polo nam tay ngắn cổ trụ AREMI chất liệu CVC mới thiết kế sang trọng thanh lịch phong cách lịch lãm APL0016
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d89'), 'shopid': 257412160, 'name': 'Áo thun polo nam ngắn tay có cổ AREMI thiết kế sang trọng phong cách trẻ trung vải cá sấu cotton APL0009', 'link': '/Áo-thun-polo-nam-ngắn-tay-có-cổ-AREMI-thiết-kế-sang-trọng-phong-cách-trẻ-trung-vải-cá-sấu-cotton-APL0009-i.257412160.21282724450', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo thun polo nam ngắn tay có cổ AREMI thiết kế sang trọng phong cách trẻ trung vải cá sấu cotton APL0009
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d8a'), 'shopid': 257412160, 'name': 'Áo polo nam tay ngắn cổ trụ AREMI chất liệu cotton cá sấu co giản 4 chiều thiết kế phong cách sang trọng APL0069', 'link': '/Áo-polo-nam-tay-ngắn-cổ-trụ-AREMI-chất-liệu-cotton-cá-sấu-co-giản-4-chiều-thiết-kế-phong-cách-sang-trọng-APL0069-i.257412160.21090639014', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo nam tay ngắn cổ trụ AREMI chất liệu cotton cá sấu co giản 4 chiều thiết kế phong cách sang trọng APL0069
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d8b'), 'shopid': 257412160, 'name': 'Áo thun nam cổ tròn tay ngắn AREMI vải cotton co giãn thấm hút tốt dày dặn thiết kế đơn giản trẻ trung ATS0009', 'link': '/Áo-thun-nam-cổ-tròn-tay-ngắn-AREMI-vải-cotton-co-giãn-thấm-hút-tốt-dày-dặn-thiết-kế-đơn-giản-trẻ-trung-ATS0009-i.257412160.3353988815', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo thun nam cổ tròn tay ngắn AREMI vải cotton co giãn thấm hút tốt dày dặn thiết kế đơn giản trẻ trung ATS0009
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d8c'), 'shopid': 257412160, 'name': 'Áo polo nam tay ngắn cổ trụ AREMI vải cotton mềm mịn cao cấp thiết kế trẻ trung thanh lịch APL0037', 'link': '/Áo-polo-nam-tay-ngắn-cổ-trụ-AREMI-vải-cotton-mềm-mịn-cao-cấp-thiết-kế-trẻ-trung-thanh-lịch-APL0037-i.257412160.21460632355', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo nam tay ngắn cổ trụ AREMI vải cotton mềm mịn cao cấp thiết kế trẻ trung thanh lịch APL0037
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d8d'), 'shopid': 257412160, 'name': 'Áo polo thun nam có cổ tay ngắn AREMI chất liệu CVC cao cấp thiết kế phong cách sang trọng tinh tế APL0035', 'link': '/Áo-polo-thun-nam-có-cổ-tay-ngắn-AREMI-chất-liệu-CVC-cao-cấp-thiết-kế-phong-cách-sang-trọng-tinh-tế-APL0035-i.257412160.13399896097', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo thun nam có cổ tay ngắn AREMI chất liệu CVC cao cấp thiết kế phong cách sang trọng tinh tế APL0035
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d8e'), 'shopid': 257412160, 'name': 'Áo polo nam tay ngắn thun nam có cổ AREMI chất liệu cá sấu cotton thiết kế phong cách sang trọng màu sắc dễ phối APL0034', 'link': '/Áo-polo-nam-tay-ngắn-thun-nam-có-cổ-AREMI-chất-liệu-cá-sấu-cotton-thiết-kế-phong-cách-sang-trọng-màu-sắc-dễ-phối-APL0034-i.257412160.18785997462', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo nam tay ngắn thun nam có cổ AREMI chất liệu cá sấu cotton thiết kế phong cách sang trọng màu sắc dễ phối APL0034
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d8f'), 'shopid': 257412160, 'name': 'Áo thun nam cổ tròn tay ngắn thiết kế AREMI phong cách trẻ trung chất liệu cotton co giản 4 chiều ATS0006', 'link': '/Áo-thun-nam-cổ-tròn-tay-ngắn-thiết-kế-AREMI-phong-cách-trẻ-trung-chất-liệu-cotton-co-giản-4-chiều-ATS0006-i.257412160.18483813846', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo thun nam cổ tròn tay ngắn thiết kế AREMI phong cách trẻ trung chất liệu cotton co giản 4 chiều ATS0006
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d90'), 'shopid': 257412160, 'name': 'Áo polo nam trơn thiết kế AREMI chất liệu cá sấu cotton co giản 4 chiều phong cách đơn giản sang trọng', 'link': '/Áo-polo-nam-trơn-thiết-kế-AREMI-chất-liệu-cá-sấu-cotton-co-giản-4-chiều-phong-cách-đơn-giản-sang-trọng-i.257412160.17899348062', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo nam trơn thiết kế AREMI chất liệu cá sấu cotton co giản 4 chiều phong cách đơn giản sang trọng
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d91'), 'shopid': 257412160, 'name': 'Áo Polo nam cổ trụ tay ngắn AREMI, thiết kế sang trọng trẻ trung phong cách lịch sự APL0075', 'link': '/Áo-Polo-nam-cổ-trụ-tay-ngắn-AREMI-thiết-kế-sang-trọng-trẻ-trung-phong-cách-lịch-sự-APL0075-i.257412160.21926412216', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo Polo nam cổ trụ tay ngắn AREMI, thiết kế sang trọng trẻ trung phong cách lịch sự APL0075
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d92'), 'shopid': 257412160, 'name': 'Áo Polo nam cổ trụ tay ngắn AREMI, màu đen in chuẩn form, thiết kế sang trọng lịch sự APL0070', 'link': '/Áo-Polo-nam-cổ-trụ-tay-ngắn-AREMI-màu-đen-in-chuẩn-form-thiết-kế-sang-trọng-lịch-sự-APL0070-i.257412160.19518818883', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo Polo nam cổ trụ tay ngắn AREMI, màu đen in chuẩn form, thiết kế sang trọng lịch sự APL0070
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d93'), 'shopid': 257412160, 'name': 'Áo polo nam thun nam có cổ AREMI chất liệu cá sấu cotton co giản 4 chiều thiết kế sang trọng APL 0015', 'link': '/Áo-polo-nam-thun-nam-có-cổ-AREMI-chất-liệu-cá-sấu-cotton-co-giản-4-chiều-thiết-kế-sang-trọng-APL-0015-i.257412160.22679886417', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo nam thun nam có cổ AREMI chất liệu cá sấu cotton co giản 4 chiều thiết kế sang trọng APL 0015
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d94'), 'shopid': 257412160, 'name': 'Áo polo nam tay ngắn có cổ AREMI vải uni cao cấp chuẩn form thiết kế phối sọc caro trẻ trung  APL0051', 'link': '/Áo-polo-nam-tay-ngắn-có-cổ-AREMI-vải-uni-cao-cấp-chuẩn-form-thiết-kế-phối-sọc-caro-trẻ-trung-APL0051-i.257412160.18279865671', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo nam tay ngắn có cổ AREMI vải uni cao cấp chuẩn form thiết kế phối sọc caro trẻ trung  APL0051
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d95'), 'shopid': 257412160, 'name': 'Áo polo nam tay ngắn cổ trụ AREMI chất liệu cá sấu cotton co giản 4 chiều thiết kế sang trọng đơn giản APL0020', 'link': '/Áo-polo-nam-tay-ngắn-cổ-trụ-AREMI-chất-liệu-cá-sấu-cotton-co-giản-4-chiều-thiết-kế-sang-trọng-đơn-giản-APL0020-i.257412160.20194649737', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo nam tay ngắn cổ trụ AREMI chất liệu cá sấu cotton co giản 4 chiều thiết kế sang trọng đơn giản APL0020
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d96'), 'shopid': 257412160, 'name': 'Áo thun cổ tròn T-shirt tay ngắn chính hãng AREMI, vải cotton 4 chiều co giãn dày dặn chuẩn form suông dành cho nam nữ', 'link': '/Áo-thun-cổ-tròn-T-shirt-tay-ngắn-chính-hãng-AREMI-vải-cotton-4-chiều-co-giãn-dày-dặn-chuẩn-form-suông-dành-cho-nam-nữ-i.257412160.20973913178', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo thun cổ tròn T-shirt tay ngắn chính hãng AREMI, vải cotton 4 chiều co giãn dày dặn chuẩn form suông dành cho nam nữ
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d97'), 'shopid': 257412160, 'name': 'Áo polo đen phối tay ngắn có cổ AREMI chuẩn form vừa vặn thiết kế độc quyền trẻ trung thanh lịch APL0045', 'link': '/Áo-polo-đen-phối-tay-ngắn-có-cổ-AREMI-chuẩn-form-vừa-vặn-thiết-kế-độc-quyền-trẻ-trung-thanh-lịch-APL0045-i.257412160.23239940502', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo đen phối tay ngắn có cổ AREMI chuẩn form vừa vặn thiết kế độc quyền trẻ trung thanh lịch APL0045
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d98'), 'shopid': 257412160, 'name': 'Áo sơ mi nam tay ngắn vải cotton AREMI thiết kế cổ vest sang trọng phong cách trẻ trung thanh lịch', 'link': '/Áo-sơ-mi-nam-tay-ngắn-vải-cotton-AREMI-thiết-kế-cổ-vest-sang-trọng-phong-cách-trẻ-trung-thanh-lịch-i.257412160.22557025453', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo sơ mi nam tay ngắn vải cotton AREMI thiết kế cổ vest sang trọng phong cách trẻ trung thanh lịch
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d99'), 'shopid': 257412160, 'name': 'Áo Polo cổ trụ thun ngắn tay thun có cổ nam AREMI, thiết kế đơn giản phối phong cách sang trọng APL0076', 'link': '/Áo-Polo-cổ-trụ-thun-ngắn-tay-thun-có-cổ-nam-AREMI-thiết-kế-đơn-giản-phối-phong-cách-sang-trọng-APL0076-i.257412160.19030192621', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo Polo cổ trụ thun ngắn tay thun có cổ nam AREMI, thiết kế đơn giản phối phong cách sang trọng APL0076
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d9a'), 'shopid': 257412160, 'name': 'Áo polo nam tay ngắn thiết kế AREMI chất liệu CVC co giản 4 chiều phong cách sang trọng thanh lịch', 'link': '/Áo-polo-nam-tay-ngắn-thiết-kế-AREMI-chất-liệu-CVC-co-giản-4-chiều-phong-cách-sang-trọng-thanh-lịch-i.257412160.23557077542', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo nam tay ngắn thiết kế AREMI chất liệu CVC co giản 4 chiều phong cách sang trọng thanh lịch
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d9b'), 'shopid': 257412160, 'name': 'Áo polo nam tay ngắn cổ trụ AREMI thiết kế mới sang trọng chất liệu cá sấu cotton co giản 4 chiều APL0072', 'link': '/Áo-polo-nam-tay-ngắn-cổ-trụ-AREMI-thiết-kế-mới-sang-trọng-chất-liệu-cá-sấu-cotton-co-giản-4-chiều-APL0072-i.257412160.20890967424', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo nam tay ngắn cổ trụ AREMI thiết kế mới sang trọng chất liệu cá sấu cotton co giản 4 chiều APL0072
# get_pc
# done one shop
# disconnecting to  ipvanish-US-Dallas-dal-a53.ovpn
# connecting to  ipvanish-US-Ashburn-iad-b31.ovpn
# start get SHOPEE_LOGIN_URL
# start input username password
# Login as : tuonggaunhql Weomtaiglsg
# Start GET
# Start GET
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d9c'), 'shopid': 257412160, 'name': 'Áo polo nam thun ngắn tay có cổ AREMI chất liệu cá sấu cotton co giản 4 chiều thiết kế sang trọng APL0003', 'link': '/Áo-polo-nam-thun-ngắn-tay-có-cổ-AREMI-chất-liệu-cá-sấu-cotton-co-giản-4-chiều-thiết-kế-sang-trọng-APL0003-i.257412160.21291416721', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo nam thun ngắn tay có cổ AREMI chất liệu cá sấu cotton co giản 4 chiều thiết kế sang trọng APL0003
# get_pc
# done one shop
# item taget :  {'_id': ObjectId('65642149154dfd3c47796d9d'), 'shopid': 257412160, 'name': 'Áo polo nam phối tay ngắn cổ trụ AREMI vải cotton cá sấu cao cấp chuẩn form thiết kế sang trọng thanh lịch APL0046', 'link': '/Áo-polo-nam-phối-tay-ngắn-cổ-trụ-AREMI-vải-cotton-cá-sấu-cao-cấp-chuẩn-form-thiết-kế-sang-trọng-thanh-lịch-APL0046-i.257412160.19378773627', 'visited': False, 'onFetching_timeout': 0}
# Seaching  Áo polo nam phối tay ngắn cổ trụ AREMI vải cotton cá sấu cao cấp chuẩn form thiết kế sang trọng thanh lịch APL0046
# get_pc
# done one shop
# 'NoneType' object is not subscriptable
# disconnecting to  ipvanish-US-Ashburn-iad-b31.ovpn

# %%
Shopee.quit_driver()
DISCONNECT_VPN(Shopee.ovpn)
# Out:
# disconnecting to  ipvanish-ES-Madrid-mad-a26.ovpn

# %%
DISCONNECT_VPN('ipvanish-US-Seattle-sea-a14.ovpn')
# Out:
# disconnecting to  ipvanish-US-Seattle-sea-a14.ovpn
