# %%
import json
import re
import pandas as pd
import scrapy
import shutil
import os
import numpy as np
import requests

# %% [markdown]
# <h1><b>THE FUCK?</b></h1>
#
# Thời trang nam

# %%
TOPIC = 'thời trang nam'
Shopee_api_official_shop_domain = 'https://shopee.vn/api/v4/official_shop/'

# %%
headers = {
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://shopee.vn/mall/',
    'Sec-Ch-Ua': '"Chromium";v="118", "Google Chrome";v="118", "Not=A?Brand";v="99"',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Ch-Ua-Platform': "Windows",
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36'
}


TOPIC_INFO = {}

url =Shopee_api_official_shop_domain + 'get_categories'
req = requests.get(url,headers=headers)
if req.status_code == 200:
        try :
            TOPIC_INFO = [i for i in req.json()['data']['categories'] if TOPIC == i['name'].lower()][0]
            print(TOPIC_INFO)
        except :
            print('Our topic is not found!')
# Out:
# {'category_id': 11035567, 'name': 'Thời Trang Nam', 'image': '687f3967b7c2fe6a134a2c11894eea4b'}

# %%
TOPIC_SHOPS = []

url = Shopee_api_official_shop_domain + f'get_shops_by_category?category_id={TOPIC_INFO["category_id"]}'
print(url)
req = requests.get(url,headers=headers)
if req.status_code == 200:
        try :
            TOPIC_SHOPS = [x for i in req.json()['data']['brands'] for x in i['brand_ids']]
            print(TOPIC_SHOPS)
        except Exception as err:
            print('Our topic has no shop!')
            print(err)
# Out:
# https://shopee.vn/api/v4/official_shop/get_shops_by_category?category_id=11035567
# ...

# %% [markdown]
# <h2>Let me introduce a new element : <i>Selchrominum<i></h2>
# the fuck is this? idk

# %%
pd.DataFrame(TOPIC_SHOPS).to_csv('Shopee_shops.csv',index=False)

# %%
shopee_shops = pd.read_csv('Shopee_shops.csv')
shopee_shops['visited'] = [False]*shopee_shops.shape[0]
shopee_shops['onFetching_timeout'] = [0]*shopee_shops.shape[0]
shopee_shops = shopee_shops.drop_duplicates(subset=['username'],keep='first')

# %%
shopee_shops = shopee_shops.to_dict('records')

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# %%
password = "MasterMind"
uri = f"mongodb+srv://MasterMind:{password}@landingpage.1i8yejw.mongodb.net/"
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db_shop_infor = client.get_database('shops')

# %%
db_shop_infor = client.get_database('shops')
records = db_shop_infor.shops

# %%
#records.insert_many(shopee_shops)
